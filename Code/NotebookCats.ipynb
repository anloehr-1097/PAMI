# %%
import os

# %%
images = os.listdir("/Users/Andy/Data/CatData/CAT_00/")
import cv2

# %%
IM_PATH = "/Users/Andy/Data/CatData/CAT_00/"

# %%
im = cv2.imread(IM_PATH + images[1])
images[1]
# Out:
# '00000081_001.jpg'

# %%
import matplotlib.pyplot as plt

# %%
cv2.imshow("image", im)

# %%
im.shape
# Out:
# (1024, 730, 3)

# %%
image_arrays = []
from pathlib import Path
for f in images:
    if Path(f).suffix == ".jpg":

        image_arrays.append(cv2.imread(IM_PATH + f))

# %%
len(image_arrays)
# Out:
# 1706

# %%
shapes = [im.shape for im in image_arrays]

# %%
image_arrays = [cv2.resize(im, (600, 600)) for im in image_arrays]
